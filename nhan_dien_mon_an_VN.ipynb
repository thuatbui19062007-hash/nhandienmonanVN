# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from keras.models import Sequential
from keras.layers import Input, Conv2D, MaxPool2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.utils import load_img
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 1. Khai báo đường dẫn và xử lý dữ liệu
train_dir = '/content/drive/MyDrive/nhận diện món ăn VN' # ĐỔI ĐƯỜNG DẪN Ở ĐÂY
img_width, img_height = 200, 200 # Đổi thành 200x200 cho nhẹ và chuẩn form
batch_size = 32

train_datagen = ImageDataGenerator(
    rescale=1/255,
    shear_range=0.2,
    zoom_range=0.2,
    height_shift_range=0.2,
    width_shift_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 300 images belonging to 6 classes.

# %%
model = Sequential([
    Input(shape=(img_width, img_height, 3)),
    Conv2D(33, (3, 3), activation='relu'),
    MaxPool2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(6, activation='softmax')
])

# %%
model.compile(optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"])
model.summary()

epochs = 100
history = model.fit(train_generator, epochs=epochs)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 198, 198, 33)   │           924 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 99, 99, 33)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 97, 97, 64)     │        19,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 48, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 46, 46, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 23, 23, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 67712)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     8,667,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,761,890 (33.42 MB)
#  Trainable params: 8,761,890 (33.42 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 175s 17s/step - accuracy: 0.1600 - loss: 2.3594
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.2400 - loss: 1.7865
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.2267 - loss: 1.7374
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.2400 - loss: 1.7368
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.2867 - loss: 1.7144
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.2600 - loss: 1.7689
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.3633 - loss: 1.5637
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.3433 - loss: 1.6181
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.3900 - loss: 1.5219
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.3733 - loss: 1.5382
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.4200 - loss: 1.4519
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.4433 - loss: 1.5028
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.4433 - loss: 1.3978
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.4767 - loss: 1.2787
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 46s 4s/step - accuracy: 0.4400 - loss: 1.3896
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.4867 - loss: 1.3106
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.5067 - loss: 1.2314
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.5467 - loss: 1.2374
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.5033 - loss: 1.2697
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.4600 - loss: 1.3347
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.5167 - loss: 1.2077
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.5500 - loss: 1.1773
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.6000 - loss: 1.1172
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.5133 - loss: 1.1950
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.5767 - loss: 1.1334
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.6000 - loss: 1.0645
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.5267 - loss: 1.2035
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.5700 - loss: 1.0736
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.5733 - loss: 1.1298
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.6000 - loss: 1.0363
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.5533 - loss: 1.1745
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.6700 - loss: 0.9130
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 44s 4s/step - accuracy: 0.5867 - loss: 1.0844
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.6500 - loss: 0.9324
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.6067 - loss: 1.0636
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.6533 - loss: 0.9722
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.6067 - loss: 1.0519
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.5667 - loss: 1.1038
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.6767 - loss: 0.9346
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.6833 - loss: 0.8407
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.6533 - loss: 0.9271
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.6600 - loss: 0.9525
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.6467 - loss: 0.8975
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.6367 - loss: 0.8753
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.6333 - loss: 1.0966
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7200 - loss: 0.8372
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.6733 - loss: 0.8367
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.6933 - loss: 0.8088
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.6967 - loss: 0.9359
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.6867 - loss: 0.8279
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.6833 - loss: 0.9037
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 73s 3s/step - accuracy: 0.7200 - loss: 0.8212
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.6733 - loss: 0.9522
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7533 - loss: 0.7001
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.6500 - loss: 1.0146
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.7367 - loss: 0.7278
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.7167 - loss: 0.8585
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.7267 - loss: 0.7553
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.6833 - loss: 0.8770
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7633 - loss: 0.6358
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7400 - loss: 0.8510
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7100 - loss: 0.8117
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7833 - loss: 0.7169
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7667 - loss: 0.6829
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7533 - loss: 0.8580
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.7500 - loss: 0.8468
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.7833 - loss: 0.6452
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7467 - loss: 0.6522
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7467 - loss: 0.7030
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7700 - loss: 0.5801
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7433 - loss: 0.7120
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7300 - loss: 0.7305
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7400 - loss: 0.7303
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7467 - loss: 0.6815
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.8100 - loss: 0.5445
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.7533 - loss: 0.7617
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.7667 - loss: 0.5753
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7967 - loss: 0.5574
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7267 - loss: 0.8261
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.8000 - loss: 0.6010
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7700 - loss: 0.5717
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.7233 - loss: 0.8455
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.8100 - loss: 0.4946
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.8033 - loss: 0.5432
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 45s 3s/step - accuracy: 0.7300 - loss: 0.8176
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.8167 - loss: 0.5323
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7600 - loss: 0.7024
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7633 - loss: 0.6049
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.7733 - loss: 0.6844
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7733 - loss: 0.7063
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.7967 - loss: 0.5463
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.7433 - loss: 0.7639
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.7700 - loss: 0.5530
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step - accuracy: 0.8100 - loss: 0.5303
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step - accuracy: 0.8200 - loss: 0.5243
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.8033 - loss: 0.6208
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.8033 - loss: 0.4727
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.8067 - loss: 0.5975
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.8333 - loss: 0.5535
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.8233 - loss: 0.4874

# %%
path = "/content/ảnhbanhxeo.png"
img = load_img(path, target_size=(img_width, img_height))
plt.imshow(img)
img = np.array(img)
img = img/255.0
img = img.reshape(1, img_width, img_height, 3)

prediction = np.argmax(model.predict(img))
class_labels = {v:k for k, v in train_generator.class_indices.items()}
dish_name = class_labels[prediction]
print(f"Món ăn tiên đoán: {dish_name}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Món ăn tiên đoán: bánh xèo
